# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#   order_id return_date        reason refund_amount approved
# 0     O102   2026/9/10   wrong size          4,500      Yes
# 1     O103  10/09/2026       DAMAGED          8000      yes
# 2     O107   2026/9/12       damaged         5,000        Y
# 3     O108     invalid  Changed Mind       unknown       No
# 4     O109   2026/9/14           NaN          2500        N
# 5     O109   2026/9/14           NaN          2500        N
