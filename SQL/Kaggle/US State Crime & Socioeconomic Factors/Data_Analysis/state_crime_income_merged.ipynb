# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/state_crime_income_merged.csv')
df
# Out:
#        State  Year  Crime Count_aggravated_assault  Crime Count_burglary  \
# 0    Alabama  2005                           11293                 43473
# 1    Alabama  2006                           10463                 44780
# 2    Alabama  2007                           11417                 45379
# 3    Alabama  2008                           11795                 50411
# 4    Alabama  2009                           13103                 48844
# ..       ...   ...                             ...                   ...
# 545  Wyoming  2011                            1010                  1864
# 546  Wyoming  2012                             932                  2125
# 547  Wyoming  2013                             917                  1956
# 548  Wyoming  2014                             899                  1689
# 549  Wyoming  2015                            1054                  1762
#
#      Crime Count_homicide  Crime Count_larceny  \
# ...

# %%
df.isnull().sum()
# Out:
# State                                                                               0
# Year                                                                                0
# Crime Count_aggravated_assault                                                      0
# Crime Count_burglary                                                                0
# Crime Count_homicide                                                                0
# Crime Count_larceny                                                                 0
# Crime Count_motor_vehicle_theft                                                     0
# Crime Count_robbery                                                                 0
# Crime Rate_aggravated_assault                                                       0
# Crime Rate_burglary                                                                 0
# Crime Rate_homicide                                                                 0
# ...
