# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv('../Datasets/sales_superstore_raw.csv')
data
# Out:
#        Row ID        Order ID           Order Date   Ship Date  \
# 0           1  US-2023-103800           03.01.2023  2023-01-07
# 1           2  US-2023-112326          04-Jan-2023  2023-01-08
# 2           3  US-2023-112326  2023-01-04 00:00:00  2023-01-08
# 3           4  US-2023-112326  2023-01-04 00:00:00  2023-01-08
# 4           5  US-2023-141817  2023-01-05 00:00:00  2023-01-12
# ...       ...             ...                  ...         ...
# 10698   10190  US-2026-143259  2026-12-30 00:00:00  2027-01-03
# 10699   10191  US-2026-115427  2026-12-30 00:00:00  2027-01-03
# 10700   10192  US-2026-156720             20261230  2027-01-03
# 10701   10193  US-2026-143259           30.12.2026  2027-01-03
# 10702   10194  CA-2026-143500           30.12.2026  2027-01-03
#
#             Ship Mode Customer ID      Customer Name      Segment  \
# 0      Standard Class    DP-13000      Darren Powers     Consumer
# 1      Standard Class    PO-19195      Phillina Ober  Home Office
# ...

# %%
data.isnull().sum()
# Out:
# Row ID               0
# Order ID             0
# Order Date           0
# Ship Date            0
# Ship Mode         1071
# Customer ID          0
# Customer Name        0
# Segment              0
# Country/Region       0
# City                 0
# State/Province       0
# Postal Code          0
# Region               0
# Product ID           0
# Category             0
# Sub-Category         0
# Product Name         0
# Sales             2038
# Quantity           537
# Discount             0
# Profit            1076
# dtype: int64
