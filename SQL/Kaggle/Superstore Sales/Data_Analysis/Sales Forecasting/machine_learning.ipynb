# %%
import pandas as pd

# %%
df = pd.read_csv('month_total_sales.csv')
df
# Out:
#                      month  total_sales
# 0   2023-01-01 00:00:00+09      17496.0
# 1   2023-02-01 00:00:00+09       7915.0
# 2   2023-03-01 00:00:00+09      50627.0
# 3   2023-04-01 00:00:00+09      24575.0
# 4   2023-05-01 00:00:00+09      22793.0
# 5   2023-06-01 00:00:00+09      28746.0
# 6   2023-07-01 00:00:00+09      34931.0
# 7   2023-08-01 00:00:00+09      24665.0
# 8   2023-09-01 00:00:00+09      71960.0
# 9   2023-10-01 00:00:00+09      27923.0
# 10  2023-11-01 00:00:00+09      70610.0
# 11  2023-12-01 00:00:00+09      62795.0
# 12  2024-01-01 00:00:00+09      20054.0
# 13  2024-02-01 00:00:00+09      11134.0
# 14  2024-03-01 00:00:00+09      36362.0
# 15  2024-04-01 00:00:00+09      32488.0
# 16  2024-05-01 00:00:00+09      23023.0
# 17  2024-06-01 00:00:00+09      24047.0
# 18  2024-07-01 00:00:00+09      26119.0
# 19  2024-08-01 00:00:00+09      28487.0
# 20  2024-09-01 00:00:00+09      54529.0
# 21  2024-10-01 00:00:00+09      26804.0
# ...

# %%
df['month'] = pd.to_datetime(df["month"])
