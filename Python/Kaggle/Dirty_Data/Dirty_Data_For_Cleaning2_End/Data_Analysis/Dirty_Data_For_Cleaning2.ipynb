# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../Datasets/Dirty_Data_For_Cleaning2.csv')
data
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
data.isnull().sum()
# Out:
# Rank                                 0
# Peak                                11
# All Time Peak                       14
# Actual gross                         0
# Adjusted gross (in 2022 dollars)     0
# Artist                               0
# Tour title                           0
# Year(s)                              0
# Shows                                0
# Average gross                        0
# Ref.                                 0
# dtype: int64

# %%
data = data.drop(['All Time Peak', 'Peak'], axis=1)
data
# Out:
#     Rank     Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     $780,000,000                     $780,000,000  Taylor Swift
# 1      2     $579,800,000                     $579,800,000       Beyoncé
# 2      3     $411,000,000                     $560,622,615       Madonna
# 3      4     $397,300,000                     $454,751,555          Pink
# 4      5     $345,675,146                     $402,844,849  Taylor Swift
# 5      6     $305,158,363                     $388,978,496       Madonna
# 6      7     $280,000,000                     $381,932,682   Celine Dion
# 7      7     $257,600,000                     $257,600,000          Pink
# 8      9     $256,084,556                     $312,258,401       Beyoncé
# 9     10     $250,400,000                     $309,141,878  Taylor Swift
# 10    11  $229,100,000[b]                     $283,202,896       Beyoncé
# 11    12     $227,400,000                     $295,301,479     Lady Gaga
# ...

# %%
data['Actual\xa0gross'] = data['Actual\xa0gross'].str.replace('$', '')
data['Actual\xa0gross'] = data['Actual\xa0gross'].str.replace(',', '')
data
# Out:
#     Rank  Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     780000000                     $780,000,000  Taylor Swift
# 1      2     579800000                     $579,800,000       Beyoncé
# 2      3     411000000                     $560,622,615       Madonna
# 3      4     397300000                     $454,751,555          Pink
# 4      5     345675146                     $402,844,849  Taylor Swift
# 5      6     305158363                     $388,978,496       Madonna
# 6      7     280000000                     $381,932,682   Celine Dion
# 7      7     257600000                     $257,600,000          Pink
# 8      9     256084556                     $312,258,401       Beyoncé
# 9     10     250400000                     $309,141,878  Taylor Swift
# 10    11  229100000[b]                     $283,202,896       Beyoncé
# 11    12     227400000                     $295,301,479     Lady Gaga
# ...

# %%
data['Adjusted\xa0gross (in 2022 dollars)'] = data['Adjusted\xa0gross (in 2022 dollars)'].str.replace('$', '')
data['Adjusted\xa0gross (in 2022 dollars)'] = data['Adjusted\xa0gross (in 2022 dollars)'].str.replace(',', '')
data
# Out:
#     Rank  Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     780000000                        780000000  Taylor Swift
# 1      2     579800000                        579800000       Beyoncé
# 2      3     411000000                        560622615       Madonna
# 3      4     397300000                        454751555          Pink
# 4      5     345675146                        402844849  Taylor Swift
# 5      6     305158363                        388978496       Madonna
# 6      7     280000000                        381932682   Celine Dion
# 7      7     257600000                        257600000          Pink
# 8      9     256084556                        312258401       Beyoncé
# 9     10     250400000                        309141878  Taylor Swift
# 10    11  229100000[b]                        283202896       Beyoncé
# 11    12     227400000                        295301479     Lady Gaga
# ...

# %%
data['Average gross'] = data['Average gross'].str.replace('$', '')
data['Average gross'] = data['Average gross'].str.replace(',', '')
data
# Out:
#     Rank  Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     780000000                        780000000  Taylor Swift
# 1      2     579800000                        579800000       Beyoncé
# 2      3     411000000                        560622615       Madonna
# 3      4     397300000                        454751555          Pink
# 4      5     345675146                        402844849  Taylor Swift
# 5      6     305158363                        388978496       Madonna
# 6      7     280000000                        381932682   Celine Dion
# 7      7     257600000                        257600000          Pink
# 8      9     256084556                        312258401       Beyoncé
# 9     10     250400000                        309141878  Taylor Swift
# 10    11  229100000[b]                        283202896       Beyoncé
# 11    12     227400000                        295301479     Lady Gaga
# ...

# %%
data['Average gross'] = data['Average gross'].str.replace(' ', '')
data
# Out:
#     Rank  Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     780000000                        780000000  Taylor Swift
# 1      2     579800000                        579800000       Beyoncé
# 2      3     411000000                        560622615       Madonna
# 3      4     397300000                        454751555          Pink
# 4      5     345675146                        402844849  Taylor Swift
# 5      6     305158363                        388978496       Madonna
# 6      7     280000000                        381932682   Celine Dion
# 7      7     257600000                        257600000          Pink
# 8      9     256084556                        312258401       Beyoncé
# 9     10     250400000                        309141878  Taylor Swift
# 10    11  229100000[b]                        283202896       Beyoncé
# 11    12     227400000                        295301479     Lady Gaga
# ...

# %%
data['Average gross'] = data['Average gross'].str.strip()

# %%
data
# Out:
#     Rank  Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     780000000                        780000000  Taylor Swift
# 1      2     579800000                        579800000       Beyoncé
# 2      3     411000000                        560622615       Madonna
# 3      4     397300000                        454751555          Pink
# 4      5     345675146                        402844849  Taylor Swift
# 5      6     305158363                        388978496       Madonna
# 6      7     280000000                        381932682   Celine Dion
# 7      7     257600000                        257600000          Pink
# 8      9     256084556                        312258401       Beyoncé
# 9     10     250400000                        309141878  Taylor Swift
# 10    11  229100000[b]                        283202896       Beyoncé
# 11    12     227400000                        295301479     Lady Gaga
# ...

# %%
data['Ref.'] = data['Ref.'].str.replace('[', '').str.replace(']', '')
data
# Out:
#     Rank  Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     780000000                        780000000  Taylor Swift
# 1      2     579800000                        579800000       Beyoncé
# 2      3     411000000                        560622615       Madonna
# 3      4     397300000                        454751555          Pink
# 4      5     345675146                        402844849  Taylor Swift
# 5      6     305158363                        388978496       Madonna
# 6      7     280000000                        381932682   Celine Dion
# 7      7     257600000                        257600000          Pink
# 8      9     256084556                        312258401       Beyoncé
# 9     10     250400000                        309141878  Taylor Swift
# 10    11  229100000[b]                        283202896       Beyoncé
# 11    12     227400000                        295301479     Lady Gaga
# ...
